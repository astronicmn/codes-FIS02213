# %%
#!/usr/bin/env python3 

'''
	<breve descrição>
   
	DESCRIÇÃO:
		<descrição + detalhada>

	AUTOR:
		N. M. Narvaz
		00318736@ufrgs.br
	
	REFERÊNCIAS: 
		<[#] referência..>
	
	BUGS/LIMITAÇÕES:

	ToDos:
		<alterações/correções a fazer>
	
	OBSERVAÇÕES:
		Para tornar executável:
		% chmod ugo+x FIS02213_09_paridade.py
		
		Para criar um link em ~/bin:
		% ln ~/prog/python/FIS02213_09_paridade.py ~/bin/FIS02213_09_paridade.py
	 
	VERSÃO:
	0.01 - <11.07.2022> 
'''

#Entra valor inteiro:
z = int( input("Digite um número: ") )

#Exemplo 1: if
if z%2==0:
	print(f"Exemplo 1: O número {z} é par.", end='\n\n')

#Exemplo 2: if-else
if z%2==0:
	print(f"Exemplo 2: O número {z} é par.", end='\n\n')
else:
	print(f"Exemplo 2: O número {z} é ímpar.", end='\n\n')

#Exemplo 3: if-else nas mesmas linhas:
if z%2==0: print(f"Exemplo 3: O número {z} é par.", end='\n\n'); print("Ok.")
else: print(f"Exemplo 3: O número {z} é ímpar.", end='\n\n')

#Exemplo 4: if, elif e else if + else = elif)
if z%2==0:
	print(f"Exemplo 4: O número {z} é divisível por 2.", end='\n\n')
elif z%3==0:
	print(f"Exemplo 4: O número {z} é divisível por 3.", end='\n\n')
else:
	print(f"Exemplo 4: O número {z} não é divisível nem por 2, nem por 3.", end='\n\n')

#Exemplo 5:
if z%2==0:
	print(f"Exemplo 5: O número {z} é divisível por 2.", end='\n\n')
elif z%3==0:
	print(f"Exemplo 5: O número {z} é divisível por 3.", end='\n\n')
elif z%5==0:
	print(f"Exemplo 5: O número {z} é divisível por 5.", end='\n\n')
elif z%7==0:
	print(f"Exemplo 5: O número {z} é divisível por 7.", end='\n\n')
else:
	print(f"Exemplo 5: O número {z} não é divisível por 2, 3, 5 ou 7.", end='\n\n')

#Exemplo 6:
if z%2==0: print(f"Exemplo 6: O número {z} é divisível por 2.", end='\n\n')
elif z%3==0: print(f"Exemplo 6: O número {z} é divisível por 3.", end='\n\n')
elif z%5==0: print(f"Exemplo 6: O número {z} é divisível por 5.", end='\n\n')
elif z%7==0: print(f"Exemplo 6: O número {z} é divisível por 7.", end='\n\n')
else: print(f"Exemplo 6: O número {z} não é divisível por 2, 3, 5 ou 7.", end='\n\n')
# Out:
# Digite um número: 10
# Exemplo 1: O número 10 é par.
#
# Exemplo 2: O número 10 é par.
#
# Exemplo 3: O número 10 é par.
#
# Ok.
# Exemplo 4: O número 10 é divisível por 2.
#
# Exemplo 5: O número 10 é divisível por 2.
#
# Exemplo 6: O número 10 é divisível por 2.
